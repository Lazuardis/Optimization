# %%
import pyomo.environ as pyo
import pandas as pd
import numpy as np

# %%
# Cost matrix data
cost_data = {
    'Unnamed: 0': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
    'Hub1': [28, 15, 35, 30, 10, 13, 34, 33],
    'Hub2': [12, 17, 25, 38, 24, 39, 15, 19],
    'Hub3': [21, 33, 10, 33, 11, 40, 22, 39],
    'Hub4': [13, 12, 32, 10, 18, 38, 36, 12],
    'Hub5': [31, 12, 11, 30, 38, 38, 17, 24]
}
cost_data
# Out:
# {'Unnamed: 0': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
#  'Hub1': [28, 15, 35, 30, 10, 13, 34, 33],
#  'Hub2': [12, 17, 25, 38, 24, 39, 15, 19],
#  'Hub3': [21, 33, 10, 33, 11, 40, 22, 39],
#  'Hub4': [13, 12, 32, 10, 18, 38, 36, 12],
#  'Hub5': [31, 12, 11, 30, 38, 38, 17, 24]}

# %%
# Load the data into a DataFrame
cost_df = pd.read_excel('cost_matrix_multi_hub.xlsx')
cost_df.set_index('Unnamed: 0', inplace=True)

# Transform the DataFrame into a dictionary for combined costs c(i, k, m, j)
cost = {}
for i in cost_df.index:
    for j in cost_df.index:
        if i != j:
            for k in cost_df.columns:
                for m in cost_df.columns:
                    if k != m:
                        cost[(i, k, m, j)] = cost_df.loc[i, k] + cost_df.loc[j, m]
                        
cost
# Out:
# {('A', 'Hub1', 'Hub2', 'B'): 45,
#  ('A', 'Hub1', 'Hub3', 'B'): 61,
#  ('A', 'Hub1', 'Hub4', 'B'): 40,
#  ('A', 'Hub1', 'Hub5', 'B'): 40,
#  ('A', 'Hub2', 'Hub1', 'B'): 27,
#  ('A', 'Hub2', 'Hub3', 'B'): 45,
#  ('A', 'Hub2', 'Hub4', 'B'): 24,
#  ('A', 'Hub2', 'Hub5', 'B'): 24,
#  ('A', 'Hub3', 'Hub1', 'B'): 36,
#  ('A', 'Hub3', 'Hub2', 'B'): 38,
#  ('A', 'Hub3', 'Hub4', 'B'): 33,
#  ('A', 'Hub3', 'Hub5', 'B'): 33,
#  ('A', 'Hub4', 'Hub1', 'B'): 28,
#  ('A', 'Hub4', 'Hub2', 'B'): 30,
#  ('A', 'Hub4', 'Hub3', 'B'): 46,
#  ('A', 'Hub4', 'Hub5', 'B'): 25,
#  ('A', 'Hub5', 'Hub1', 'B'): 46,
#  ('A', 'Hub5', 'Hub2', 'B'): 48,
#  ('A', 'Hub5', 'Hub3', 'B'): 64,
#  ('A', 'Hub5', 'Hub4', 'B'): 43,
#  ('A', 'Hub1', 'Hub2', 'C'): 53,
#  ('A', 'Hub1', 'Hub3', 'C'): 38,
#  ('A', 'Hub1', 'Hub4', 'C'): 60,
#  ('A', 'Hub1', 'Hub5', 'C'): 39,
#  ('A', 'Hub2', 'Hub1', 'C'): 47,
#  ('A', 'Hub2', 'Hub3', 'C'): 22,
#  ('A', 'Hub2', 'Hub4', 'C'): 44,
#  ('A', 'Hub2', 'Hub5', 'C'): 23,
#  ('A', 'Hub3', 'Hub1', 'C'): 56,
#  ('A', 'Hub3', 'Hub2', 'C'): 46,
#  ('A', 'Hub3', 'Hub4', 'C'): 53,
#  ('A', 'Hub3', 'Hub5', 'C'): 32,
#  ('A', 'Hub4', 'Hub1', 'C'): 48,
#  ('A', 'Hub4', 'Hub2', 'C'): 38,
#  ('A', 'Hub4', 'Hub3', 'C'): 23,
#  ('A', 'Hub4', 'Hub5', 'C'): 24,
#  ('A', 'Hub5', 'Hub1', 'C'): 66,
#  ('A', 'Hub5', 'Hub2', 'C'): 56,
#  ('A', 'Hub5', 'Hub3', 'C'): 41,
#  ('A', 'Hub5', 'Hub4', 'C'): 63,
#  ('A', 'Hub1', 'Hub2', 'D'): 66,
#  ('A', 'Hub1', 'Hub3', 'D'): 61,
#  ('A', 'Hub1', 'Hub4', 'D'): 38,
#  ('A', 'Hub1', 'Hub5', 'D'): 58,
#  ('A', 'Hub2', 'Hub1', 'D'): 42,
#  ('A', 'Hub2', 'Hub3', 'D'): 45,
#  ('A', 'Hub2', 'Hub4', 'D'): 22,
#  ('A', 'Hub2', 'Hub5', 'D'): 42,
#  ('A', 'Hub3', 'Hub1', 'D'): 51,
#  ('A', 'Hub3', 'Hub2', 'D'): 59,
#  ('A', 'Hub3', 'Hub4', 'D'): 31,
#  ('A', 'Hub3', 'Hub5', 'D'): 51,
#  ('A', 'Hub4', 'Hub1', 'D'): 43,
#  ('A', 'Hub4', 'Hub2', 'D'): 51,
#  ('A', 'Hub4', 'Hub3', 'D'): 46,
#  ('A', 'Hub4', 'Hub5', 'D'): 43,
#  ('A', 'Hub5', 'Hub1', 'D'): 61,
#  ('A', 'Hub5', 'Hub2', 'D'): 69,
#  ('A', 'Hub5', 'Hub3', 'D'): 64,
#  ('A', 'Hub5', 'Hub4', 'D'): 41,
#  ('A', 'Hub1', 'Hub2', 'E'): 52,
#  ('A', 'Hub1', 'Hub3', 'E'): 39,
#  ('A', 'Hub1', 'Hub4', 'E'): 46,
#  ('A', 'Hub1', 'Hub5', 'E'): 66,
#  ('A', 'Hub2', 'Hub1', 'E'): 22,
#  ('A', 'Hub2', 'Hub3', 'E'): 23,
#  ('A', 'Hub2', 'Hub4', 'E'): 30,
#  ('A', 'Hub2', 'Hub5', 'E'): 50,
#  ('A', 'Hub3', 'Hub1', 'E'): 31,
#  ('A', 'Hub3', 'Hub2', 'E'): 45,
#  ('A', 'Hub3', 'Hub4', 'E'): 39,
#  ('A', 'Hub3', 'Hub5', 'E'): 59,
#  ('A', 'Hub4', 'Hub1', 'E'): 23,
#  ('A', 'Hub4', 'Hub2', 'E'): 37,
#  ('A', 'Hub4', 'Hub3', 'E'): 24,
#  ('A', 'Hub4', 'Hub5', 'E'): 51,
#  ('A', 'Hub5', 'Hub1', 'E'): 41,
#  ('A', 'Hub5', 'Hub2', 'E'): 55,
#  ('A', 'Hub5', 'Hub3', 'E'): 42,
#  ('A', 'Hub5', 'Hub4', 'E'): 49,
#  ('A', 'Hub1', 'Hub2', 'F'): 67,
#  ('A', 'Hub1', 'Hub3', 'F'): 68,
#  ('A', 'Hub1', 'Hub4', 'F'): 66,
#  ('A', 'Hub1', 'Hub5', 'F'): 66,
#  ('A', 'Hub2', 'Hub1', 'F'): 25,
#  ('A', 'Hub2', 'Hub3', 'F'): 52,
#  ('A', 'Hub2', 'Hub4', 'F'): 50,
#  ('A', 'Hub2', 'Hub5', 'F'): 50,
#  ('A', 'Hub3', 'Hub1', 'F'): 34,
#  ('A', 'Hub3', 'Hub2', 'F'): 60,
#  ('A', 'Hub3', 'Hub4', 'F'): 59,
#  ('A', 'Hub3', 'Hub5', 'F'): 59,
#  ('A', 'Hub4', 'Hub1', 'F'): 26,
#  ('A', 'Hub4', 'Hub2', 'F'): 52,
#  ('A', 'Hub4', 'Hub3', 'F'): 53,
#  ('A', 'Hub4', 'Hub5', 'F'): 51,
#  ('A', 'Hub5', 'Hub1', 'F'): 44,
#  ('A', 'Hub5', 'Hub2', 'F'): 70,
#  ('A', 'Hub5', 'Hub3', 'F'): 71,
#  ('A', 'Hub5', 'Hub4', 'F'): 69,
#  ('A', 'Hub1', 'Hub2', 'G'): 43,
#  ('A', 'Hub1', 'Hub3', 'G'): 50,
#  ('A', 'Hub1', 'Hub4', 'G'): 64,
#  ('A', 'Hub1', 'Hub5', 'G'): 45,
#  ('A', 'Hub2', 'Hub1', 'G'): 46,
#  ('A', 'Hub2', 'Hub3', 'G'): 34,
#  ('A', 'Hub2', 'Hub4', 'G'): 48,
#  ('A', 'Hub2', 'Hub5', 'G'): 29,
#  ('A', 'Hub3', 'Hub1', 'G'): 55,
#  ('A', 'Hub3', 'Hub2', 'G'): 36,
#  ('A', 'Hub3', 'Hub4', 'G'): 57,
#  ('A', 'Hub3', 'Hub5', 'G'): 38,
#  ('A', 'Hub4', 'Hub1', 'G'): 47,
#  ('A', 'Hub4', 'Hub2', 'G'): 28,
#  ('A', 'Hub4', 'Hub3', 'G'): 35,
#  ('A', 'Hub4', 'Hub5', 'G'): 30,
#  ('A', 'Hub5', 'Hub1', 'G'): 65,
#  ('A', 'Hub5', 'Hub2', 'G'): 46,
#  ('A', 'Hub5', 'Hub3', 'G'): 53,
#  ('A', 'Hub5', 'Hub4', 'G'): 67,
#  ('A', 'Hub1', 'Hub2', 'H'): 47,
#  ('A', 'Hub1', 'Hub3', 'H'): 67,
#  ('A', 'Hub1', 'Hub4', 'H'): 40,
#  ('A', 'Hub1', 'Hub5', 'H'): 52,
#  ('A', 'Hub2', 'Hub1', 'H'): 45,
#  ('A', 'Hub2', 'Hub3', 'H'): 51,
#  ('A', 'Hub2', 'Hub4', 'H'): 24,
#  ('A', 'Hub2', 'Hub5', 'H'): 36,
#  ('A', 'Hub3', 'Hub1', 'H'): 54,
#  ('A', 'Hub3', 'Hub2', 'H'): 40,
#  ('A', 'Hub3', 'Hub4', 'H'): 33,
#  ('A', 'Hub3', 'Hub5', 'H'): 45,
#  ('A', 'Hub4', 'Hub1', 'H'): 46,
#  ('A', 'Hub4', 'Hub2', 'H'): 32,
#  ('A', 'Hub4', 'Hub3', 'H'): 52,
#  ('A', 'Hub4', 'Hub5', 'H'): 37,
#  ('A', 'Hub5', 'Hub1', 'H'): 64,
#  ('A', 'Hub5', 'Hub2', 'H'): 50,
#  ('A', 'Hub5', 'Hub3', 'H'): 70,
#  ('A', 'Hub5', 'Hub4', 'H'): 43,
#  ('B', 'Hub1', 'Hub2', 'A'): 27,
#  ('B', 'Hub1', 'Hub3', 'A'): 36,
#  ('B', 'Hub1', 'Hub4', 'A'): 28,
#  ('B', 'Hub1', 'Hub5', 'A'): 46,
#  ('B', 'Hub2', 'Hub1', 'A'): 45,
#  ('B', 'Hub2', 'Hub3', 'A'): 38,
#  ('B', 'Hub2', 'Hub4', 'A'): 30,
#  ('B', 'Hub2', 'Hub5', 'A'): 48,
#  ('B', 'Hub3', 'Hub1', 'A'): 61,
#  ('B', 'Hub3', 'Hub2', 'A'): 45,
#  ('B', 'Hub3', 'Hub4', 'A'): 46,
#  ('B', 'Hub3', 'Hub5', 'A'): 64,
#  ('B', 'Hub4', 'Hub1', 'A'): 40,
#  ('B', 'Hub4', 'Hub2', 'A'): 24,
#  ('B', 'Hub4', 'Hub3', 'A'): 33,
#  ('B', 'Hub4', 'Hub5', 'A'): 43,
#  ('B', 'Hub5', 'Hub1', 'A'): 40,
#  ('B', 'Hub5', 'Hub2', 'A'): 24,
#  ('B', 'Hub5', 'Hub3', 'A'): 33,
#  ('B', 'Hub5', 'Hub4', 'A'): 25,
#  ('B', 'Hub1', 'Hub2', 'C'): 40,
#  ('B', 'Hub1', 'Hub3', 'C'): 25,
#  ('B', 'Hub1', 'Hub4', 'C'): 47,
#  ('B', 'Hub1', 'Hub5', 'C'): 26,
#  ('B', 'Hub2', 'Hub1', 'C'): 52,
#  ('B', 'Hub2', 'Hub3', 'C'): 27,
#  ('B', 'Hub2', 'Hub4', 'C'): 49,
#  ('B', 'Hub2', 'Hub5', 'C'): 28,
#  ('B', 'Hub3', 'Hub1', 'C'): 68,
#  ('B', 'Hub3', 'Hub2', 'C'): 58,
#  ('B', 'Hub3', 'Hub4', 'C'): 65,
#  ('B', 'Hub3', 'Hub5', 'C'): 44,
#  ('B', 'Hub4', 'Hub1', 'C'): 47,
#  ('B', 'Hub4', 'Hub2', 'C'): 37,
#  ('B', 'Hub4', 'Hub3', 'C'): 22,
#  ('B', 'Hub4', 'Hub5', 'C'): 23,
#  ('B', 'Hub5', 'Hub1', 'C'): 47,
#  ('B', 'Hub5', 'Hub2', 'C'): 37,
#  ('B', 'Hub5', 'Hub3', 'C'): 22,
#  ('B', 'Hub5', 'Hub4', 'C'): 44,
#  ('B', 'Hub1', 'Hub2', 'D'): 53,
#  ('B', 'Hub1', 'Hub3', 'D'): 48,
#  ('B', 'Hub1', 'Hub4', 'D'): 25,
#  ('B', 'Hub1', 'Hub5', 'D'): 45,
#  ('B', 'Hub2', 'Hub1', 'D'): 47,
#  ('B', 'Hub2', 'Hub3', 'D'): 50,
#  ('B', 'Hub2', 'Hub4', 'D'): 27,
#  ('B', 'Hub2', 'Hub5', 'D'): 47,
#  ('B', 'Hub3', 'Hub1', 'D'): 63,
#  ('B', 'Hub3', 'Hub2', 'D'): 71,
#  ('B', 'Hub3', 'Hub4', 'D'): 43,
#  ('B', 'Hub3', 'Hub5', 'D'): 63,
#  ('B', 'Hub4', 'Hub1', 'D'): 42,
#  ('B', 'Hub4', 'Hub2', 'D'): 50,
#  ('B', 'Hub4', 'Hub3', 'D'): 45,
#  ('B', 'Hub4', 'Hub5', 'D'): 42,
#  ('B', 'Hub5', 'Hub1', 'D'): 42,
#  ('B', 'Hub5', 'Hub2', 'D'): 50,
#  ('B', 'Hub5', 'Hub3', 'D'): 45,
#  ('B', 'Hub5', 'Hub4', 'D'): 22,
#  ('B', 'Hub1', 'Hub2', 'E'): 39,
#  ('B', 'Hub1', 'Hub3', 'E'): 26,
#  ('B', 'Hub1', 'Hub4', 'E'): 33,
#  ('B', 'Hub1', 'Hub5', 'E'): 53,
#  ('B', 'Hub2', 'Hub1', 'E'): 27,
#  ('B', 'Hub2', 'Hub3', 'E'): 28,
#  ('B', 'Hub2', 'Hub4', 'E'): 35,
#  ('B', 'Hub2', 'Hub5', 'E'): 55,
#  ('B', 'Hub3', 'Hub1', 'E'): 43,
#  ('B', 'Hub3', 'Hub2', 'E'): 57,
#  ('B', 'Hub3', 'Hub4', 'E'): 51,
#  ('B', 'Hub3', 'Hub5', 'E'): 71,
#  ('B', 'Hub4', 'Hub1', 'E'): 22,
#  ('B', 'Hub4', 'Hub2', 'E'): 36,
#  ('B', 'Hub4', 'Hub3', 'E'): 23,
#  ('B', 'Hub4', 'Hub5', 'E'): 50,
#  ('B', 'Hub5', 'Hub1', 'E'): 22,
#  ('B', 'Hub5', 'Hub2', 'E'): 36,
#  ('B', 'Hub5', 'Hub3', 'E'): 23,
#  ('B', 'Hub5', 'Hub4', 'E'): 30,
#  ('B', 'Hub1', 'Hub2', 'F'): 54,
#  ('B', 'Hub1', 'Hub3', 'F'): 55,
#  ('B', 'Hub1', 'Hub4', 'F'): 53,
#  ('B', 'Hub1', 'Hub5', 'F'): 53,
#  ('B', 'Hub2', 'Hub1', 'F'): 30,
#  ('B', 'Hub2', 'Hub3', 'F'): 57,
#  ('B', 'Hub2', 'Hub4', 'F'): 55,
#  ('B', 'Hub2', 'Hub5', 'F'): 55,
#  ('B', 'Hub3', 'Hub1', 'F'): 46,
#  ('B', 'Hub3', 'Hub2', 'F'): 72,
#  ('B', 'Hub3', 'Hub4', 'F'): 71,
#  ('B', 'Hub3', 'Hub5', 'F'): 71,
#  ('B', 'Hub4', 'Hub1', 'F'): 25,
#  ('B', 'Hub4', 'Hub2', 'F'): 51,
#  ('B', 'Hub4', 'Hub3', 'F'): 52,
#  ('B', 'Hub4', 'Hub5', 'F'): 50,
#  ('B', 'Hub5', 'Hub1', 'F'): 25,
#  ('B', 'Hub5', 'Hub2', 'F'): 51,
#  ('B', 'Hub5', 'Hub3', 'F'): 52,
#  ('B', 'Hub5', 'Hub4', 'F'): 50,
#  ('B', 'Hub1', 'Hub2', 'G'): 30,
#  ('B', 'Hub1', 'Hub3', 'G'): 37,
#  ('B', 'Hub1', 'Hub4', 'G'): 51,
#  ('B', 'Hub1', 'Hub5', 'G'): 32,
#  ('B', 'Hub2', 'Hub1', 'G'): 51,
#  ('B', 'Hub2', 'Hub3', 'G'): 39,
#  ('B', 'Hub2', 'Hub4', 'G'): 53,
#  ('B', 'Hub2', 'Hub5', 'G'): 34,
#  ('B', 'Hub3', 'Hub1', 'G'): 67,
#  ('B', 'Hub3', 'Hub2', 'G'): 48,
#  ('B', 'Hub3', 'Hub4', 'G'): 69,
#  ('B', 'Hub3', 'Hub5', 'G'): 50,
#  ('B', 'Hub4', 'Hub1', 'G'): 46,
#  ('B', 'Hub4', 'Hub2', 'G'): 27,
#  ('B', 'Hub4', 'Hub3', 'G'): 34,
#  ('B', 'Hub4', 'Hub5', 'G'): 29,
#  ('B', 'Hub5', 'Hub1', 'G'): 46,
#  ('B', 'Hub5', 'Hub2', 'G'): 27,
#  ('B', 'Hub5', 'Hub3', 'G'): 34,
#  ('B', 'Hub5', 'Hub4', 'G'): 48,
#  ('B', 'Hub1', 'Hub2', 'H'): 34,
#  ('B', 'Hub1', 'Hub3', 'H'): 54,
#  ('B', 'Hub1', 'Hub4', 'H'): 27,
#  ('B', 'Hub1', 'Hub5', 'H'): 39,
#  ('B', 'Hub2', 'Hub1', 'H'): 50,
#  ('B', 'Hub2', 'Hub3', 'H'): 56,
#  ('B', 'Hub2', 'Hub4', 'H'): 29,
#  ('B', 'Hub2', 'Hub5', 'H'): 41,
#  ('B', 'Hub3', 'Hub1', 'H'): 66,
#  ('B', 'Hub3', 'Hub2', 'H'): 52,
#  ('B', 'Hub3', 'Hub4', 'H'): 45,
#  ('B', 'Hub3', 'Hub5', 'H'): 57,
#  ('B', 'Hub4', 'Hub1', 'H'): 45,
#  ('B', 'Hub4', 'Hub2', 'H'): 31,
#  ('B', 'Hub4', 'Hub3', 'H'): 51,
#  ('B', 'Hub4', 'Hub5', 'H'): 36,
#  ('B', 'Hub5', 'Hub1', 'H'): 45,
#  ('B', 'Hub5', 'Hub2', 'H'): 31,
#  ('B', 'Hub5', 'Hub3', 'H'): 51,
#  ('B', 'Hub5', 'Hub4', 'H'): 24,
#  ('C', 'Hub1', 'Hub2', 'A'): 47,
#  ('C', 'Hub1', 'Hub3', 'A'): 56,
#  ('C', 'Hub1', 'Hub4', 'A'): 48,
#  ('C', 'Hub1', 'Hub5', 'A'): 66,
#  ('C', 'Hub2', 'Hub1', 'A'): 53,
#  ('C', 'Hub2', 'Hub3', 'A'): 46,
#  ('C', 'Hub2', 'Hub4', 'A'): 38,
#  ('C', 'Hub2', 'Hub5', 'A'): 56,
#  ('C', 'Hub3', 'Hub1', 'A'): 38,
#  ('C', 'Hub3', 'Hub2', 'A'): 22,
#  ('C', 'Hub3', 'Hub4', 'A'): 23,
#  ('C', 'Hub3', 'Hub5', 'A'): 41,
#  ('C', 'Hub4', 'Hub1', 'A'): 60,
#  ('C', 'Hub4', 'Hub2', 'A'): 44,
#  ('C', 'Hub4', 'Hub3', 'A'): 53,
#  ('C', 'Hub4', 'Hub5', 'A'): 63,
#  ('C', 'Hub5', 'Hub1', 'A'): 39,
#  ('C', 'Hub5', 'Hub2', 'A'): 23,
#  ('C', 'Hub5', 'Hub3', 'A'): 32,
#  ('C', 'Hub5', 'Hub4', 'A'): 24,
#  ('C', 'Hub1', 'Hub2', 'B'): 52,
#  ('C', 'Hub1', 'Hub3', 'B'): 68,
#  ('C', 'Hub1', 'Hub4', 'B'): 47,
#  ('C', 'Hub1', 'Hub5', 'B'): 47,
#  ('C', 'Hub2', 'Hub1', 'B'): 40,
#  ('C', 'Hub2', 'Hub3', 'B'): 58,
#  ('C', 'Hub2', 'Hub4', 'B'): 37,
#  ('C', 'Hub2', 'Hub5', 'B'): 37,
#  ('C', 'Hub3', 'Hub1', 'B'): 25,
#  ('C', 'Hub3', 'Hub2', 'B'): 27,
#  ('C', 'Hub3', 'Hub4', 'B'): 22,
#  ('C', 'Hub3', 'Hub5', 'B'): 22,
#  ('C', 'Hub4', 'Hub1', 'B'): 47,
#  ('C', 'Hub4', 'Hub2', 'B'): 49,
#  ('C', 'Hub4', 'Hub3', 'B'): 65,
#  ('C', 'Hub4', 'Hub5', 'B'): 44,
#  ('C', 'Hub5', 'Hub1', 'B'): 26,
#  ('C', 'Hub5', 'Hub2', 'B'): 28,
#  ('C', 'Hub5', 'Hub3', 'B'): 44,
#  ('C', 'Hub5', 'Hub4', 'B'): 23,
#  ('C', 'Hub1', 'Hub2', 'D'): 73,
#  ('C', 'Hub1', 'Hub3', 'D'): 68,
#  ('C', 'Hub1', 'Hub4', 'D'): 45,
#  ('C', 'Hub1', 'Hub5', 'D'): 65,
#  ('C', 'Hub2', 'Hub1', 'D'): 55,
#  ('C', 'Hub2', 'Hub3', 'D'): 58,
#  ('C', 'Hub2', 'Hub4', 'D'): 35,
#  ('C', 'Hub2', 'Hub5', 'D'): 55,
#  ('C', 'Hub3', 'Hub1', 'D'): 40,
#  ('C', 'Hub3', 'Hub2', 'D'): 48,
#  ('C', 'Hub3', 'Hub4', 'D'): 20,
#  ('C', 'Hub3', 'Hub5', 'D'): 40,
#  ('C', 'Hub4', 'Hub1', 'D'): 62,
#  ('C', 'Hub4', 'Hub2', 'D'): 70,
#  ('C', 'Hub4', 'Hub3', 'D'): 65,
#  ('C', 'Hub4', 'Hub5', 'D'): 62,
#  ('C', 'Hub5', 'Hub1', 'D'): 41,
#  ('C', 'Hub5', 'Hub2', 'D'): 49,
#  ('C', 'Hub5', 'Hub3', 'D'): 44,
#  ('C', 'Hub5', 'Hub4', 'D'): 21,
#  ('C', 'Hub1', 'Hub2', 'E'): 59,
#  ('C', 'Hub1', 'Hub3', 'E'): 46,
#  ('C', 'Hub1', 'Hub4', 'E'): 53,
#  ('C', 'Hub1', 'Hub5', 'E'): 73,
#  ('C', 'Hub2', 'Hub1', 'E'): 35,
#  ('C', 'Hub2', 'Hub3', 'E'): 36,
#  ('C', 'Hub2', 'Hub4', 'E'): 43,
#  ('C', 'Hub2', 'Hub5', 'E'): 63,
#  ('C', 'Hub3', 'Hub1', 'E'): 20,
#  ('C', 'Hub3', 'Hub2', 'E'): 34,
#  ('C', 'Hub3', 'Hub4', 'E'): 28,
#  ('C', 'Hub3', 'Hub5', 'E'): 48,
#  ('C', 'Hub4', 'Hub1', 'E'): 42,
#  ('C', 'Hub4', 'Hub2', 'E'): 56,
#  ('C', 'Hub4', 'Hub3', 'E'): 43,
#  ('C', 'Hub4', 'Hub5', 'E'): 70,
#  ('C', 'Hub5', 'Hub1', 'E'): 21,
#  ('C', 'Hub5', 'Hub2', 'E'): 35,
#  ('C', 'Hub5', 'Hub3', 'E'): 22,
#  ('C', 'Hub5', 'Hub4', 'E'): 29,
#  ('C', 'Hub1', 'Hub2', 'F'): 74,
#  ('C', 'Hub1', 'Hub3', 'F'): 75,
#  ('C', 'Hub1', 'Hub4', 'F'): 73,
#  ('C', 'Hub1', 'Hub5', 'F'): 73,
#  ('C', 'Hub2', 'Hub1', 'F'): 38,
#  ('C', 'Hub2', 'Hub3', 'F'): 65,
#  ('C', 'Hub2', 'Hub4', 'F'): 63,
#  ('C', 'Hub2', 'Hub5', 'F'): 63,
#  ('C', 'Hub3', 'Hub1', 'F'): 23,
#  ('C', 'Hub3', 'Hub2', 'F'): 49,
#  ('C', 'Hub3', 'Hub4', 'F'): 48,
#  ('C', 'Hub3', 'Hub5', 'F'): 48,
#  ('C', 'Hub4', 'Hub1', 'F'): 45,
#  ('C', 'Hub4', 'Hub2', 'F'): 71,
#  ('C', 'Hub4', 'Hub3', 'F'): 72,
#  ('C', 'Hub4', 'Hub5', 'F'): 70,
#  ('C', 'Hub5', 'Hub1', 'F'): 24,
#  ('C', 'Hub5', 'Hub2', 'F'): 50,
#  ('C', 'Hub5', 'Hub3', 'F'): 51,
#  ('C', 'Hub5', 'Hub4', 'F'): 49,
#  ('C', 'Hub1', 'Hub2', 'G'): 50,
#  ('C', 'Hub1', 'Hub3', 'G'): 57,
#  ('C', 'Hub1', 'Hub4', 'G'): 71,
#  ('C', 'Hub1', 'Hub5', 'G'): 52,
#  ('C', 'Hub2', 'Hub1', 'G'): 59,
#  ('C', 'Hub2', 'Hub3', 'G'): 47,
#  ('C', 'Hub2', 'Hub4', 'G'): 61,
#  ('C', 'Hub2', 'Hub5', 'G'): 42,
#  ('C', 'Hub3', 'Hub1', 'G'): 44,
#  ('C', 'Hub3', 'Hub2', 'G'): 25,
#  ('C', 'Hub3', 'Hub4', 'G'): 46,
#  ('C', 'Hub3', 'Hub5', 'G'): 27,
#  ('C', 'Hub4', 'Hub1', 'G'): 66,
#  ('C', 'Hub4', 'Hub2', 'G'): 47,
#  ('C', 'Hub4', 'Hub3', 'G'): 54,
#  ('C', 'Hub4', 'Hub5', 'G'): 49,
#  ('C', 'Hub5', 'Hub1', 'G'): 45,
#  ('C', 'Hub5', 'Hub2', 'G'): 26,
#  ('C', 'Hub5', 'Hub3', 'G'): 33,
#  ('C', 'Hub5', 'Hub4', 'G'): 47,
#  ('C', 'Hub1', 'Hub2', 'H'): 54,
#  ('C', 'Hub1', 'Hub3', 'H'): 74,
#  ('C', 'Hub1', 'Hub4', 'H'): 47,
#  ('C', 'Hub1', 'Hub5', 'H'): 59,
#  ('C', 'Hub2', 'Hub1', 'H'): 58,
#  ('C', 'Hub2', 'Hub3', 'H'): 64,
#  ('C', 'Hub2', 'Hub4', 'H'): 37,
#  ('C', 'Hub2', 'Hub5', 'H'): 49,
#  ('C', 'Hub3', 'Hub1', 'H'): 43,
#  ('C', 'Hub3', 'Hub2', 'H'): 29,
#  ('C', 'Hub3', 'Hub4', 'H'): 22,
#  ('C', 'Hub3', 'Hub5', 'H'): 34,
#  ('C', 'Hub4', 'Hub1', 'H'): 65,
#  ('C', 'Hub4', 'Hub2', 'H'): 51,
#  ('C', 'Hub4', 'Hub3', 'H'): 71,
#  ('C', 'Hub4', 'Hub5', 'H'): 56,
#  ('C', 'Hub5', 'Hub1', 'H'): 44,
#  ('C', 'Hub5', 'Hub2', 'H'): 30,
#  ('C', 'Hub5', 'Hub3', 'H'): 50,
#  ('C', 'Hub5', 'Hub4', 'H'): 23,
#  ('D', 'Hub1', 'Hub2', 'A'): 42,
#  ('D', 'Hub1', 'Hub3', 'A'): 51,
#  ('D', 'Hub1', 'Hub4', 'A'): 43,
#  ('D', 'Hub1', 'Hub5', 'A'): 61,
#  ('D', 'Hub2', 'Hub1', 'A'): 66,
#  ('D', 'Hub2', 'Hub3', 'A'): 59,
#  ('D', 'Hub2', 'Hub4', 'A'): 51,
#  ('D', 'Hub2', 'Hub5', 'A'): 69,
#  ('D', 'Hub3', 'Hub1', 'A'): 61,
#  ('D', 'Hub3', 'Hub2', 'A'): 45,
#  ('D', 'Hub3', 'Hub4', 'A'): 46,
#  ('D', 'Hub3', 'Hub5', 'A'): 64,
#  ('D', 'Hub4', 'Hub1', 'A'): 38,
#  ('D', 'Hub4', 'Hub2', 'A'): 22,
#  ('D', 'Hub4', 'Hub3', 'A'): 31,
#  ('D', 'Hub4', 'Hub5', 'A'): 41,
#  ('D', 'Hub5', 'Hub1', 'A'): 58,
#  ('D', 'Hub5', 'Hub2', 'A'): 42,
#  ('D', 'Hub5', 'Hub3', 'A'): 51,
#  ('D', 'Hub5', 'Hub4', 'A'): 43,
#  ('D', 'Hub1', 'Hub2', 'B'): 47,
#  ('D', 'Hub1', 'Hub3', 'B'): 63,
#  ('D', 'Hub1', 'Hub4', 'B'): 42,
#  ('D', 'Hub1', 'Hub5', 'B'): 42,
#  ('D', 'Hub2', 'Hub1', 'B'): 53,
#  ('D', 'Hub2', 'Hub3', 'B'): 71,
#  ('D', 'Hub2', 'Hub4', 'B'): 50,
#  ('D', 'Hub2', 'Hub5', 'B'): 50,
#  ('D', 'Hub3', 'Hub1', 'B'): 48,
#  ('D', 'Hub3', 'Hub2', 'B'): 50,
#  ('D', 'Hub3', 'Hub4', 'B'): 45,
#  ('D', 'Hub3', 'Hub5', 'B'): 45,
#  ('D', 'Hub4', 'Hub1', 'B'): 25,
#  ('D', 'Hub4', 'Hub2', 'B'): 27,
#  ('D', 'Hub4', 'Hub3', 'B'): 43,
#  ('D', 'Hub4', 'Hub5', 'B'): 22,
#  ('D', 'Hub5', 'Hub1', 'B'): 45,
#  ('D', 'Hub5', 'Hub2', 'B'): 47,
#  ('D', 'Hub5', 'Hub3', 'B'): 63,
#  ('D', 'Hub5', 'Hub4', 'B'): 42,
#  ('D', 'Hub1', 'Hub2', 'C'): 55,
#  ('D', 'Hub1', 'Hub3', 'C'): 40,
#  ('D', 'Hub1', 'Hub4', 'C'): 62,
#  ('D', 'Hub1', 'Hub5', 'C'): 41,
#  ('D', 'Hub2', 'Hub1', 'C'): 73,
#  ('D', 'Hub2', 'Hub3', 'C'): 48,
#  ('D', 'Hub2', 'Hub4', 'C'): 70,
#  ('D', 'Hub2', 'Hub5', 'C'): 49,
#  ('D', 'Hub3', 'Hub1', 'C'): 68,
#  ('D', 'Hub3', 'Hub2', 'C'): 58,
#  ('D', 'Hub3', 'Hub4', 'C'): 65,
#  ('D', 'Hub3', 'Hub5', 'C'): 44,
#  ('D', 'Hub4', 'Hub1', 'C'): 45,
#  ('D', 'Hub4', 'Hub2', 'C'): 35,
#  ('D', 'Hub4', 'Hub3', 'C'): 20,
#  ('D', 'Hub4', 'Hub5', 'C'): 21,
#  ('D', 'Hub5', 'Hub1', 'C'): 65,
#  ('D', 'Hub5', 'Hub2', 'C'): 55,
#  ('D', 'Hub5', 'Hub3', 'C'): 40,
#  ('D', 'Hub5', 'Hub4', 'C'): 62,
#  ('D', 'Hub1', 'Hub2', 'E'): 54,
#  ('D', 'Hub1', 'Hub3', 'E'): 41,
#  ('D', 'Hub1', 'Hub4', 'E'): 48,
#  ('D', 'Hub1', 'Hub5', 'E'): 68,
#  ('D', 'Hub2', 'Hub1', 'E'): 48,
#  ('D', 'Hub2', 'Hub3', 'E'): 49,
#  ('D', 'Hub2', 'Hub4', 'E'): 56,
#  ('D', 'Hub2', 'Hub5', 'E'): 76,
#  ('D', 'Hub3', 'Hub1', 'E'): 43,
#  ('D', 'Hub3', 'Hub2', 'E'): 57,
#  ('D', 'Hub3', 'Hub4', 'E'): 51,
#  ('D', 'Hub3', 'Hub5', 'E'): 71,
#  ('D', 'Hub4', 'Hub1', 'E'): 20,
#  ('D', 'Hub4', 'Hub2', 'E'): 34,
#  ('D', 'Hub4', 'Hub3', 'E'): 21,
#  ('D', 'Hub4', 'Hub5', 'E'): 48,
#  ('D', 'Hub5', 'Hub1', 'E'): 40,
#  ('D', 'Hub5', 'Hub2', 'E'): 54,
#  ('D', 'Hub5', 'Hub3', 'E'): 41,
#  ('D', 'Hub5', 'Hub4', 'E'): 48,
#  ('D', 'Hub1', 'Hub2', 'F'): 69,
#  ('D', 'Hub1', 'Hub3', 'F'): 70,
#  ('D', 'Hub1', 'Hub4', 'F'): 68,
#  ('D', 'Hub1', 'Hub5', 'F'): 68,
#  ('D', 'Hub2', 'Hub1', 'F'): 51,
#  ('D', 'Hub2', 'Hub3', 'F'): 78,
#  ('D', 'Hub2', 'Hub4', 'F'): 76,
#  ('D', 'Hub2', 'Hub5', 'F'): 76,
#  ('D', 'Hub3', 'Hub1', 'F'): 46,
#  ('D', 'Hub3', 'Hub2', 'F'): 72,
#  ('D', 'Hub3', 'Hub4', 'F'): 71,
#  ('D', 'Hub3', 'Hub5', 'F'): 71,
#  ('D', 'Hub4', 'Hub1', 'F'): 23,
#  ('D', 'Hub4', 'Hub2', 'F'): 49,
#  ('D', 'Hub4', 'Hub3', 'F'): 50,
#  ('D', 'Hub4', 'Hub5', 'F'): 48,
#  ('D', 'Hub5', 'Hub1', 'F'): 43,
#  ('D', 'Hub5', 'Hub2', 'F'): 69,
#  ('D', 'Hub5', 'Hub3', 'F'): 70,
#  ('D', 'Hub5', 'Hub4', 'F'): 68,
#  ('D', 'Hub1', 'Hub2', 'G'): 45,
#  ('D', 'Hub1', 'Hub3', 'G'): 52,
#  ('D', 'Hub1', 'Hub4', 'G'): 66,
#  ('D', 'Hub1', 'Hub5', 'G'): 47,
#  ('D', 'Hub2', 'Hub1', 'G'): 72,
#  ('D', 'Hub2', 'Hub3', 'G'): 60,
#  ('D', 'Hub2', 'Hub4', 'G'): 74,
#  ('D', 'Hub2', 'Hub5', 'G'): 55,
#  ('D', 'Hub3', 'Hub1', 'G'): 67,
#  ('D', 'Hub3', 'Hub2', 'G'): 48,
#  ('D', 'Hub3', 'Hub4', 'G'): 69,
#  ('D', 'Hub3', 'Hub5', 'G'): 50,
#  ('D', 'Hub4', 'Hub1', 'G'): 44,
#  ('D', 'Hub4', 'Hub2', 'G'): 25,
#  ('D', 'Hub4', 'Hub3', 'G'): 32,
#  ('D', 'Hub4', 'Hub5', 'G'): 27,
#  ('D', 'Hub5', 'Hub1', 'G'): 64,
#  ('D', 'Hub5', 'Hub2', 'G'): 45,
#  ('D', 'Hub5', 'Hub3', 'G'): 52,
#  ('D', 'Hub5', 'Hub4', 'G'): 66,
#  ('D', 'Hub1', 'Hub2', 'H'): 49,
#  ('D', 'Hub1', 'Hub3', 'H'): 69,
#  ('D', 'Hub1', 'Hub4', 'H'): 42,
#  ('D', 'Hub1', 'Hub5', 'H'): 54,
#  ('D', 'Hub2', 'Hub1', 'H'): 71,
#  ('D', 'Hub2', 'Hub3', 'H'): 77,
#  ('D', 'Hub2', 'Hub4', 'H'): 50,
#  ('D', 'Hub2', 'Hub5', 'H'): 62,
#  ('D', 'Hub3', 'Hub1', 'H'): 66,
#  ('D', 'Hub3', 'Hub2', 'H'): 52,
#  ('D', 'Hub3', 'Hub4', 'H'): 45,
#  ('D', 'Hub3', 'Hub5', 'H'): 57,
#  ('D', 'Hub4', 'Hub1', 'H'): 43,
#  ('D', 'Hub4', 'Hub2', 'H'): 29,
#  ('D', 'Hub4', 'Hub3', 'H'): 49,
#  ('D', 'Hub4', 'Hub5', 'H'): 34,
#  ('D', 'Hub5', 'Hub1', 'H'): 63,
#  ('D', 'Hub5', 'Hub2', 'H'): 49,
#  ('D', 'Hub5', 'Hub3', 'H'): 69,
#  ('D', 'Hub5', 'Hub4', 'H'): 42,
#  ('E', 'Hub1', 'Hub2', 'A'): 22,
#  ('E', 'Hub1', 'Hub3', 'A'): 31,
#  ('E', 'Hub1', 'Hub4', 'A'): 23,
#  ('E', 'Hub1', 'Hub5', 'A'): 41,
#  ('E', 'Hub2', 'Hub1', 'A'): 52,
#  ('E', 'Hub2', 'Hub3', 'A'): 45,
#  ('E', 'Hub2', 'Hub4', 'A'): 37,
#  ('E', 'Hub2', 'Hub5', 'A'): 55,
#  ('E', 'Hub3', 'Hub1', 'A'): 39,
#  ('E', 'Hub3', 'Hub2', 'A'): 23,
#  ('E', 'Hub3', 'Hub4', 'A'): 24,
#  ('E', 'Hub3', 'Hub5', 'A'): 42,
#  ('E', 'Hub4', 'Hub1', 'A'): 46,
#  ('E', 'Hub4', 'Hub2', 'A'): 30,
#  ('E', 'Hub4', 'Hub3', 'A'): 39,
#  ('E', 'Hub4', 'Hub5', 'A'): 49,
#  ('E', 'Hub5', 'Hub1', 'A'): 66,
#  ('E', 'Hub5', 'Hub2', 'A'): 50,
#  ('E', 'Hub5', 'Hub3', 'A'): 59,
#  ('E', 'Hub5', 'Hub4', 'A'): 51,
#  ('E', 'Hub1', 'Hub2', 'B'): 27,
#  ('E', 'Hub1', 'Hub3', 'B'): 43,
#  ('E', 'Hub1', 'Hub4', 'B'): 22,
#  ('E', 'Hub1', 'Hub5', 'B'): 22,
#  ('E', 'Hub2', 'Hub1', 'B'): 39,
#  ('E', 'Hub2', 'Hub3', 'B'): 57,
#  ('E', 'Hub2', 'Hub4', 'B'): 36,
#  ('E', 'Hub2', 'Hub5', 'B'): 36,
#  ('E', 'Hub3', 'Hub1', 'B'): 26,
#  ('E', 'Hub3', 'Hub2', 'B'): 28,
#  ('E', 'Hub3', 'Hub4', 'B'): 23,
#  ('E', 'Hub3', 'Hub5', 'B'): 23,
#  ('E', 'Hub4', 'Hub1', 'B'): 33,
#  ('E', 'Hub4', 'Hub2', 'B'): 35,
#  ('E', 'Hub4', 'Hub3', 'B'): 51,
#  ('E', 'Hub4', 'Hub5', 'B'): 30,
#  ('E', 'Hub5', 'Hub1', 'B'): 53,
#  ('E', 'Hub5', 'Hub2', 'B'): 55,
#  ('E', 'Hub5', 'Hub3', 'B'): 71,
#  ('E', 'Hub5', 'Hub4', 'B'): 50,
#  ('E', 'Hub1', 'Hub2', 'C'): 35,
#  ('E', 'Hub1', 'Hub3', 'C'): 20,
#  ('E', 'Hub1', 'Hub4', 'C'): 42,
#  ('E', 'Hub1', 'Hub5', 'C'): 21,
#  ('E', 'Hub2', 'Hub1', 'C'): 59,
#  ('E', 'Hub2', 'Hub3', 'C'): 34,
#  ('E', 'Hub2', 'Hub4', 'C'): 56,
#  ('E', 'Hub2', 'Hub5', 'C'): 35,
#  ('E', 'Hub3', 'Hub1', 'C'): 46,
#  ('E', 'Hub3', 'Hub2', 'C'): 36,
#  ('E', 'Hub3', 'Hub4', 'C'): 43,
#  ('E', 'Hub3', 'Hub5', 'C'): 22,
#  ('E', 'Hub4', 'Hub1', 'C'): 53,
#  ('E', 'Hub4', 'Hub2', 'C'): 43,
#  ('E', 'Hub4', 'Hub3', 'C'): 28,
#  ('E', 'Hub4', 'Hub5', 'C'): 29,
#  ('E', 'Hub5', 'Hub1', 'C'): 73,
#  ('E', 'Hub5', 'Hub2', 'C'): 63,
#  ('E', 'Hub5', 'Hub3', 'C'): 48,
#  ('E', 'Hub5', 'Hub4', 'C'): 70,
#  ('E', 'Hub1', 'Hub2', 'D'): 48,
#  ('E', 'Hub1', 'Hub3', 'D'): 43,
#  ('E', 'Hub1', 'Hub4', 'D'): 20,
#  ('E', 'Hub1', 'Hub5', 'D'): 40,
#  ('E', 'Hub2', 'Hub1', 'D'): 54,
#  ('E', 'Hub2', 'Hub3', 'D'): 57,
#  ('E', 'Hub2', 'Hub4', 'D'): 34,
#  ('E', 'Hub2', 'Hub5', 'D'): 54,
#  ('E', 'Hub3', 'Hub1', 'D'): 41,
#  ('E', 'Hub3', 'Hub2', 'D'): 49,
#  ('E', 'Hub3', 'Hub4', 'D'): 21,
#  ('E', 'Hub3', 'Hub5', 'D'): 41,
#  ('E', 'Hub4', 'Hub1', 'D'): 48,
#  ('E', 'Hub4', 'Hub2', 'D'): 56,
#  ('E', 'Hub4', 'Hub3', 'D'): 51,
#  ('E', 'Hub4', 'Hub5', 'D'): 48,
#  ('E', 'Hub5', 'Hub1', 'D'): 68,
#  ('E', 'Hub5', 'Hub2', 'D'): 76,
#  ('E', 'Hub5', 'Hub3', 'D'): 71,
#  ('E', 'Hub5', 'Hub4', 'D'): 48,
#  ('E', 'Hub1', 'Hub2', 'F'): 49,
#  ('E', 'Hub1', 'Hub3', 'F'): 50,
#  ('E', 'Hub1', 'Hub4', 'F'): 48,
#  ('E', 'Hub1', 'Hub5', 'F'): 48,
#  ('E', 'Hub2', 'Hub1', 'F'): 37,
#  ('E', 'Hub2', 'Hub3', 'F'): 64,
#  ('E', 'Hub2', 'Hub4', 'F'): 62,
#  ('E', 'Hub2', 'Hub5', 'F'): 62,
#  ('E', 'Hub3', 'Hub1', 'F'): 24,
#  ('E', 'Hub3', 'Hub2', 'F'): 50,
#  ('E', 'Hub3', 'Hub4', 'F'): 49,
#  ('E', 'Hub3', 'Hub5', 'F'): 49,
#  ('E', 'Hub4', 'Hub1', 'F'): 31,
#  ('E', 'Hub4', 'Hub2', 'F'): 57,
#  ('E', 'Hub4', 'Hub3', 'F'): 58,
#  ('E', 'Hub4', 'Hub5', 'F'): 56,
#  ('E', 'Hub5', 'Hub1', 'F'): 51,
#  ('E', 'Hub5', 'Hub2', 'F'): 77,
#  ('E', 'Hub5', 'Hub3', 'F'): 78,
#  ('E', 'Hub5', 'Hub4', 'F'): 76,
#  ('E', 'Hub1', 'Hub2', 'G'): 25,
#  ('E', 'Hub1', 'Hub3', 'G'): 32,
#  ('E', 'Hub1', 'Hub4', 'G'): 46,
#  ('E', 'Hub1', 'Hub5', 'G'): 27,
#  ('E', 'Hub2', 'Hub1', 'G'): 58,
#  ('E', 'Hub2', 'Hub3', 'G'): 46,
#  ('E', 'Hub2', 'Hub4', 'G'): 60,
#  ('E', 'Hub2', 'Hub5', 'G'): 41,
#  ('E', 'Hub3', 'Hub1', 'G'): 45,
#  ('E', 'Hub3', 'Hub2', 'G'): 26,
#  ('E', 'Hub3', 'Hub4', 'G'): 47,
#  ('E', 'Hub3', 'Hub5', 'G'): 28,
#  ('E', 'Hub4', 'Hub1', 'G'): 52,
#  ('E', 'Hub4', 'Hub2', 'G'): 33,
#  ('E', 'Hub4', 'Hub3', 'G'): 40,
#  ('E', 'Hub4', 'Hub5', 'G'): 35,
#  ('E', 'Hub5', 'Hub1', 'G'): 72,
#  ('E', 'Hub5', 'Hub2', 'G'): 53,
#  ('E', 'Hub5', 'Hub3', 'G'): 60,
#  ('E', 'Hub5', 'Hub4', 'G'): 74,
#  ('E', 'Hub1', 'Hub2', 'H'): 29,
#  ('E', 'Hub1', 'Hub3', 'H'): 49,
#  ('E', 'Hub1', 'Hub4', 'H'): 22,
#  ('E', 'Hub1', 'Hub5', 'H'): 34,
#  ('E', 'Hub2', 'Hub1', 'H'): 57,
#  ('E', 'Hub2', 'Hub3', 'H'): 63,
#  ('E', 'Hub2', 'Hub4', 'H'): 36,
#  ('E', 'Hub2', 'Hub5', 'H'): 48,
#  ('E', 'Hub3', 'Hub1', 'H'): 44,
#  ('E', 'Hub3', 'Hub2', 'H'): 30,
#  ('E', 'Hub3', 'Hub4', 'H'): 23,
#  ('E', 'Hub3', 'Hub5', 'H'): 35,
#  ('E', 'Hub4', 'Hub1', 'H'): 51,
#  ('E', 'Hub4', 'Hub2', 'H'): 37,
#  ('E', 'Hub4', 'Hub3', 'H'): 57,
#  ('E', 'Hub4', 'Hub5', 'H'): 42,
#  ('E', 'Hub5', 'Hub1', 'H'): 71,
#  ('E', 'Hub5', 'Hub2', 'H'): 57,
#  ('E', 'Hub5', 'Hub3', 'H'): 77,
#  ('E', 'Hub5', 'Hub4', 'H'): 50,
#  ('F', 'Hub1', 'Hub2', 'A'): 25,
#  ('F', 'Hub1', 'Hub3', 'A'): 34,
#  ('F', 'Hub1', 'Hub4', 'A'): 26,
#  ('F', 'Hub1', 'Hub5', 'A'): 44,
#  ('F', 'Hub2', 'Hub1', 'A'): 67,
#  ('F', 'Hub2', 'Hub3', 'A'): 60,
#  ('F', 'Hub2', 'Hub4', 'A'): 52,
#  ('F', 'Hub2', 'Hub5', 'A'): 70,
#  ('F', 'Hub3', 'Hub1', 'A'): 68,
#  ('F', 'Hub3', 'Hub2', 'A'): 52,
#  ('F', 'Hub3', 'Hub4', 'A'): 53,
#  ('F', 'Hub3', 'Hub5', 'A'): 71,
#  ('F', 'Hub4', 'Hub1', 'A'): 66,
#  ('F', 'Hub4', 'Hub2', 'A'): 50,
#  ('F', 'Hub4', 'Hub3', 'A'): 59,
#  ('F', 'Hub4', 'Hub5', 'A'): 69,
#  ('F', 'Hub5', 'Hub1', 'A'): 66,
#  ('F', 'Hub5', 'Hub2', 'A'): 50,
#  ('F', 'Hub5', 'Hub3', 'A'): 59,
#  ('F', 'Hub5', 'Hub4', 'A'): 51,
#  ('F', 'Hub1', 'Hub2', 'B'): 30,
#  ('F', 'Hub1', 'Hub3', 'B'): 46,
#  ('F', 'Hub1', 'Hub4', 'B'): 25,
#  ('F', 'Hub1', 'Hub5', 'B'): 25,
#  ('F', 'Hub2', 'Hub1', 'B'): 54,
#  ('F', 'Hub2', 'Hub3', 'B'): 72,
#  ('F', 'Hub2', 'Hub4', 'B'): 51,
#  ('F', 'Hub2', 'Hub5', 'B'): 51,
#  ('F', 'Hub3', 'Hub1', 'B'): 55,
#  ('F', 'Hub3', 'Hub2', 'B'): 57,
#  ('F', 'Hub3', 'Hub4', 'B'): 52,
#  ('F', 'Hub3', 'Hub5', 'B'): 52,
#  ('F', 'Hub4', 'Hub1', 'B'): 53,
#  ('F', 'Hub4', 'Hub2', 'B'): 55,
#  ('F', 'Hub4', 'Hub3', 'B'): 71,
#  ('F', 'Hub4', 'Hub5', 'B'): 50,
#  ('F', 'Hub5', 'Hub1', 'B'): 53,
#  ('F', 'Hub5', 'Hub2', 'B'): 55,
#  ('F', 'Hub5', 'Hub3', 'B'): 71,
#  ('F', 'Hub5', 'Hub4', 'B'): 50,
#  ('F', 'Hub1', 'Hub2', 'C'): 38,
#  ('F', 'Hub1', 'Hub3', 'C'): 23,
#  ('F', 'Hub1', 'Hub4', 'C'): 45,
#  ('F', 'Hub1', 'Hub5', 'C'): 24,
#  ('F', 'Hub2', 'Hub1', 'C'): 74,
#  ('F', 'Hub2', 'Hub3', 'C'): 49,
#  ('F', 'Hub2', 'Hub4', 'C'): 71,
#  ('F', 'Hub2', 'Hub5', 'C'): 50,
#  ('F', 'Hub3', 'Hub1', 'C'): 75,
#  ('F', 'Hub3', 'Hub2', 'C'): 65,
#  ('F', 'Hub3', 'Hub4', 'C'): 72,
#  ('F', 'Hub3', 'Hub5', 'C'): 51,
#  ('F', 'Hub4', 'Hub1', 'C'): 73,
#  ('F', 'Hub4', 'Hub2', 'C'): 63,
#  ('F', 'Hub4', 'Hub3', 'C'): 48,
#  ('F', 'Hub4', 'Hub5', 'C'): 49,
#  ('F', 'Hub5', 'Hub1', 'C'): 73,
#  ('F', 'Hub5', 'Hub2', 'C'): 63,
#  ('F', 'Hub5', 'Hub3', 'C'): 48,
#  ('F', 'Hub5', 'Hub4', 'C'): 70,
#  ('F', 'Hub1', 'Hub2', 'D'): 51,
#  ('F', 'Hub1', 'Hub3', 'D'): 46,
#  ('F', 'Hub1', 'Hub4', 'D'): 23,
#  ('F', 'Hub1', 'Hub5', 'D'): 43,
#  ('F', 'Hub2', 'Hub1', 'D'): 69,
#  ('F', 'Hub2', 'Hub3', 'D'): 72,
#  ('F', 'Hub2', 'Hub4', 'D'): 49,
#  ('F', 'Hub2', 'Hub5', 'D'): 69,
#  ('F', 'Hub3', 'Hub1', 'D'): 70,
#  ('F', 'Hub3', 'Hub2', 'D'): 78,
#  ('F', 'Hub3', 'Hub4', 'D'): 50,
#  ('F', 'Hub3', 'Hub5', 'D'): 70,
#  ('F', 'Hub4', 'Hub1', 'D'): 68,
#  ('F', 'Hub4', 'Hub2', 'D'): 76,
#  ('F', 'Hub4', 'Hub3', 'D'): 71,
#  ('F', 'Hub4', 'Hub5', 'D'): 68,
#  ('F', 'Hub5', 'Hub1', 'D'): 68,
#  ('F', 'Hub5', 'Hub2', 'D'): 76,
#  ('F', 'Hub5', 'Hub3', 'D'): 71,
#  ('F', 'Hub5', 'Hub4', 'D'): 48,
#  ('F', 'Hub1', 'Hub2', 'E'): 37,
#  ('F', 'Hub1', 'Hub3', 'E'): 24,
#  ('F', 'Hub1', 'Hub4', 'E'): 31,
#  ('F', 'Hub1', 'Hub5', 'E'): 51,
#  ('F', 'Hub2', 'Hub1', 'E'): 49,
#  ('F', 'Hub2', 'Hub3', 'E'): 50,
#  ('F', 'Hub2', 'Hub4', 'E'): 57,
#  ('F', 'Hub2', 'Hub5', 'E'): 77,
#  ('F', 'Hub3', 'Hub1', 'E'): 50,
#  ('F', 'Hub3', 'Hub2', 'E'): 64,
#  ('F', 'Hub3', 'Hub4', 'E'): 58,
#  ('F', 'Hub3', 'Hub5', 'E'): 78,
#  ('F', 'Hub4', 'Hub1', 'E'): 48,
#  ('F', 'Hub4', 'Hub2', 'E'): 62,
#  ('F', 'Hub4', 'Hub3', 'E'): 49,
#  ('F', 'Hub4', 'Hub5', 'E'): 76,
#  ('F', 'Hub5', 'Hub1', 'E'): 48,
#  ('F', 'Hub5', 'Hub2', 'E'): 62,
#  ('F', 'Hub5', 'Hub3', 'E'): 49,
#  ('F', 'Hub5', 'Hub4', 'E'): 56,
#  ('F', 'Hub1', 'Hub2', 'G'): 28,
#  ('F', 'Hub1', 'Hub3', 'G'): 35,
#  ('F', 'Hub1', 'Hub4', 'G'): 49,
#  ('F', 'Hub1', 'Hub5', 'G'): 30,
#  ('F', 'Hub2', 'Hub1', 'G'): 73,
#  ('F', 'Hub2', 'Hub3', 'G'): 61,
#  ('F', 'Hub2', 'Hub4', 'G'): 75,
#  ('F', 'Hub2', 'Hub5', 'G'): 56,
#  ('F', 'Hub3', 'Hub1', 'G'): 74,
#  ('F', 'Hub3', 'Hub2', 'G'): 55,
#  ('F', 'Hub3', 'Hub4', 'G'): 76,
#  ('F', 'Hub3', 'Hub5', 'G'): 57,
#  ('F', 'Hub4', 'Hub1', 'G'): 72,
#  ('F', 'Hub4', 'Hub2', 'G'): 53,
#  ('F', 'Hub4', 'Hub3', 'G'): 60,
#  ('F', 'Hub4', 'Hub5', 'G'): 55,
#  ('F', 'Hub5', 'Hub1', 'G'): 72,
#  ('F', 'Hub5', 'Hub2', 'G'): 53,
#  ('F', 'Hub5', 'Hub3', 'G'): 60,
#  ('F', 'Hub5', 'Hub4', 'G'): 74,
#  ('F', 'Hub1', 'Hub2', 'H'): 32,
#  ('F', 'Hub1', 'Hub3', 'H'): 52,
#  ('F', 'Hub1', 'Hub4', 'H'): 25,
#  ('F', 'Hub1', 'Hub5', 'H'): 37,
#  ('F', 'Hub2', 'Hub1', 'H'): 72,
#  ('F', 'Hub2', 'Hub3', 'H'): 78,
#  ('F', 'Hub2', 'Hub4', 'H'): 51,
#  ('F', 'Hub2', 'Hub5', 'H'): 63,
#  ('F', 'Hub3', 'Hub1', 'H'): 73,
#  ('F', 'Hub3', 'Hub2', 'H'): 59,
#  ('F', 'Hub3', 'Hub4', 'H'): 52,
#  ('F', 'Hub3', 'Hub5', 'H'): 64,
#  ('F', 'Hub4', 'Hub1', 'H'): 71,
#  ('F', 'Hub4', 'Hub2', 'H'): 57,
#  ('F', 'Hub4', 'Hub3', 'H'): 77,
#  ('F', 'Hub4', 'Hub5', 'H'): 62,
#  ('F', 'Hub5', 'Hub1', 'H'): 71,
#  ('F', 'Hub5', 'Hub2', 'H'): 57,
#  ('F', 'Hub5', 'Hub3', 'H'): 77,
#  ('F', 'Hub5', 'Hub4', 'H'): 50,
#  ('G', 'Hub1', 'Hub2', 'A'): 46,
#  ('G', 'Hub1', 'Hub3', 'A'): 55,
#  ('G', 'Hub1', 'Hub4', 'A'): 47,
#  ('G', 'Hub1', 'Hub5', 'A'): 65,
#  ('G', 'Hub2', 'Hub1', 'A'): 43,
#  ('G', 'Hub2', 'Hub3', 'A'): 36,
#  ('G', 'Hub2', 'Hub4', 'A'): 28,
#  ('G', 'Hub2', 'Hub5', 'A'): 46,
#  ('G', 'Hub3', 'Hub1', 'A'): 50,
#  ('G', 'Hub3', 'Hub2', 'A'): 34,
#  ('G', 'Hub3', 'Hub4', 'A'): 35,
#  ('G', 'Hub3', 'Hub5', 'A'): 53,
#  ('G', 'Hub4', 'Hub1', 'A'): 64,
#  ('G', 'Hub4', 'Hub2', 'A'): 48,
#  ('G', 'Hub4', 'Hub3', 'A'): 57,
#  ('G', 'Hub4', 'Hub5', 'A'): 67,
#  ('G', 'Hub5', 'Hub1', 'A'): 45,
#  ('G', 'Hub5', 'Hub2', 'A'): 29,
#  ('G', 'Hub5', 'Hub3', 'A'): 38,
#  ('G', 'Hub5', 'Hub4', 'A'): 30,
#  ('G', 'Hub1', 'Hub2', 'B'): 51,
#  ('G', 'Hub1', 'Hub3', 'B'): 67,
#  ('G', 'Hub1', 'Hub4', 'B'): 46,
#  ('G', 'Hub1', 'Hub5', 'B'): 46,
#  ('G', 'Hub2', 'Hub1', 'B'): 30,
#  ('G', 'Hub2', 'Hub3', 'B'): 48,
#  ('G', 'Hub2', 'Hub4', 'B'): 27,
#  ('G', 'Hub2', 'Hub5', 'B'): 27,
#  ('G', 'Hub3', 'Hub1', 'B'): 37,
#  ('G', 'Hub3', 'Hub2', 'B'): 39,
#  ('G', 'Hub3', 'Hub4', 'B'): 34,
#  ('G', 'Hub3', 'Hub5', 'B'): 34,
#  ('G', 'Hub4', 'Hub1', 'B'): 51,
#  ('G', 'Hub4', 'Hub2', 'B'): 53,
#  ('G', 'Hub4', 'Hub3', 'B'): 69,
#  ('G', 'Hub4', 'Hub5', 'B'): 48,
#  ('G', 'Hub5', 'Hub1', 'B'): 32,
#  ('G', 'Hub5', 'Hub2', 'B'): 34,
#  ('G', 'Hub5', 'Hub3', 'B'): 50,
#  ('G', 'Hub5', 'Hub4', 'B'): 29,
#  ('G', 'Hub1', 'Hub2', 'C'): 59,
#  ('G', 'Hub1', 'Hub3', 'C'): 44,
#  ('G', 'Hub1', 'Hub4', 'C'): 66,
#  ('G', 'Hub1', 'Hub5', 'C'): 45,
#  ('G', 'Hub2', 'Hub1', 'C'): 50,
#  ('G', 'Hub2', 'Hub3', 'C'): 25,
#  ('G', 'Hub2', 'Hub4', 'C'): 47,
#  ('G', 'Hub2', 'Hub5', 'C'): 26,
#  ('G', 'Hub3', 'Hub1', 'C'): 57,
#  ('G', 'Hub3', 'Hub2', 'C'): 47,
#  ('G', 'Hub3', 'Hub4', 'C'): 54,
#  ('G', 'Hub3', 'Hub5', 'C'): 33,
#  ('G', 'Hub4', 'Hub1', 'C'): 71,
#  ('G', 'Hub4', 'Hub2', 'C'): 61,
#  ('G', 'Hub4', 'Hub3', 'C'): 46,
#  ('G', 'Hub4', 'Hub5', 'C'): 47,
#  ('G', 'Hub5', 'Hub1', 'C'): 52,
#  ('G', 'Hub5', 'Hub2', 'C'): 42,
#  ('G', 'Hub5', 'Hub3', 'C'): 27,
#  ('G', 'Hub5', 'Hub4', 'C'): 49,
#  ('G', 'Hub1', 'Hub2', 'D'): 72,
#  ('G', 'Hub1', 'Hub3', 'D'): 67,
#  ('G', 'Hub1', 'Hub4', 'D'): 44,
#  ('G', 'Hub1', 'Hub5', 'D'): 64,
#  ('G', 'Hub2', 'Hub1', 'D'): 45,
#  ('G', 'Hub2', 'Hub3', 'D'): 48,
#  ('G', 'Hub2', 'Hub4', 'D'): 25,
#  ('G', 'Hub2', 'Hub5', 'D'): 45,
#  ('G', 'Hub3', 'Hub1', 'D'): 52,
#  ('G', 'Hub3', 'Hub2', 'D'): 60,
#  ('G', 'Hub3', 'Hub4', 'D'): 32,
#  ('G', 'Hub3', 'Hub5', 'D'): 52,
#  ('G', 'Hub4', 'Hub1', 'D'): 66,
#  ('G', 'Hub4', 'Hub2', 'D'): 74,
#  ('G', 'Hub4', 'Hub3', 'D'): 69,
#  ('G', 'Hub4', 'Hub5', 'D'): 66,
#  ('G', 'Hub5', 'Hub1', 'D'): 47,
#  ('G', 'Hub5', 'Hub2', 'D'): 55,
#  ('G', 'Hub5', 'Hub3', 'D'): 50,
#  ('G', 'Hub5', 'Hub4', 'D'): 27,
#  ('G', 'Hub1', 'Hub2', 'E'): 58,
#  ('G', 'Hub1', 'Hub3', 'E'): 45,
#  ('G', 'Hub1', 'Hub4', 'E'): 52,
#  ('G', 'Hub1', 'Hub5', 'E'): 72,
#  ('G', 'Hub2', 'Hub1', 'E'): 25,
#  ('G', 'Hub2', 'Hub3', 'E'): 26,
#  ('G', 'Hub2', 'Hub4', 'E'): 33,
#  ('G', 'Hub2', 'Hub5', 'E'): 53,
#  ('G', 'Hub3', 'Hub1', 'E'): 32,
#  ('G', 'Hub3', 'Hub2', 'E'): 46,
#  ('G', 'Hub3', 'Hub4', 'E'): 40,
#  ('G', 'Hub3', 'Hub5', 'E'): 60,
#  ('G', 'Hub4', 'Hub1', 'E'): 46,
#  ('G', 'Hub4', 'Hub2', 'E'): 60,
#  ('G', 'Hub4', 'Hub3', 'E'): 47,
#  ('G', 'Hub4', 'Hub5', 'E'): 74,
#  ('G', 'Hub5', 'Hub1', 'E'): 27,
#  ('G', 'Hub5', 'Hub2', 'E'): 41,
#  ('G', 'Hub5', 'Hub3', 'E'): 28,
#  ('G', 'Hub5', 'Hub4', 'E'): 35,
#  ('G', 'Hub1', 'Hub2', 'F'): 73,
#  ('G', 'Hub1', 'Hub3', 'F'): 74,
#  ('G', 'Hub1', 'Hub4', 'F'): 72,
#  ('G', 'Hub1', 'Hub5', 'F'): 72,
#  ('G', 'Hub2', 'Hub1', 'F'): 28,
#  ('G', 'Hub2', 'Hub3', 'F'): 55,
#  ('G', 'Hub2', 'Hub4', 'F'): 53,
#  ('G', 'Hub2', 'Hub5', 'F'): 53,
#  ('G', 'Hub3', 'Hub1', 'F'): 35,
#  ('G', 'Hub3', 'Hub2', 'F'): 61,
#  ('G', 'Hub3', 'Hub4', 'F'): 60,
#  ('G', 'Hub3', 'Hub5', 'F'): 60,
#  ('G', 'Hub4', 'Hub1', 'F'): 49,
#  ('G', 'Hub4', 'Hub2', 'F'): 75,
#  ('G', 'Hub4', 'Hub3', 'F'): 76,
#  ('G', 'Hub4', 'Hub5', 'F'): 74,
#  ('G', 'Hub5', 'Hub1', 'F'): 30,
#  ('G', 'Hub5', 'Hub2', 'F'): 56,
#  ('G', 'Hub5', 'Hub3', 'F'): 57,
#  ('G', 'Hub5', 'Hub4', 'F'): 55,
#  ('G', 'Hub1', 'Hub2', 'H'): 53,
#  ('G', 'Hub1', 'Hub3', 'H'): 73,
#  ('G', 'Hub1', 'Hub4', 'H'): 46,
#  ('G', 'Hub1', 'Hub5', 'H'): 58,
#  ('G', 'Hub2', 'Hub1', 'H'): 48,
#  ('G', 'Hub2', 'Hub3', 'H'): 54,
#  ('G', 'Hub2', 'Hub4', 'H'): 27,
#  ('G', 'Hub2', 'Hub5', 'H'): 39,
#  ('G', 'Hub3', 'Hub1', 'H'): 55,
#  ('G', 'Hub3', 'Hub2', 'H'): 41,
#  ('G', 'Hub3', 'Hub4', 'H'): 34,
#  ('G', 'Hub3', 'Hub5', 'H'): 46,
#  ('G', 'Hub4', 'Hub1', 'H'): 69,
#  ('G', 'Hub4', 'Hub2', 'H'): 55,
#  ('G', 'Hub4', 'Hub3', 'H'): 75,
#  ('G', 'Hub4', 'Hub5', 'H'): 60,
#  ('G', 'Hub5', 'Hub1', 'H'): 50,
#  ('G', 'Hub5', 'Hub2', 'H'): 36,
#  ('G', 'Hub5', 'Hub3', 'H'): 56,
#  ('G', 'Hub5', 'Hub4', 'H'): 29,
#  ('H', 'Hub1', 'Hub2', 'A'): 45,
#  ('H', 'Hub1', 'Hub3', 'A'): 54,
#  ('H', 'Hub1', 'Hub4', 'A'): 46,
#  ('H', 'Hub1', 'Hub5', 'A'): 64,
#  ('H', 'Hub2', 'Hub1', 'A'): 47,
#  ('H', 'Hub2', 'Hub3', 'A'): 40,
#  ('H', 'Hub2', 'Hub4', 'A'): 32,
#  ('H', 'Hub2', 'Hub5', 'A'): 50,
#  ('H', 'Hub3', 'Hub1', 'A'): 67,
#  ('H', 'Hub3', 'Hub2', 'A'): 51,
#  ('H', 'Hub3', 'Hub4', 'A'): 52,
#  ('H', 'Hub3', 'Hub5', 'A'): 70,
#  ('H', 'Hub4', 'Hub1', 'A'): 40,
#  ('H', 'Hub4', 'Hub2', 'A'): 24,
#  ('H', 'Hub4', 'Hub3', 'A'): 33,
#  ('H', 'Hub4', 'Hub5', 'A'): 43,
#  ('H', 'Hub5', 'Hub1', 'A'): 52,
#  ('H', 'Hub5', 'Hub2', 'A'): 36,
#  ('H', 'Hub5', 'Hub3', 'A'): 45,
#  ('H', 'Hub5', 'Hub4', 'A'): 37,
#  ...}

# %%
# Initialize the model
model = pyo.ConcreteModel()

# Define sets
nodes = list(cost_df.index)
hubs = list(cost_df.columns)
pairs = [(i, j) for i in nodes for j in nodes if i != j]
hub_pairs = [(k, m) for k in hubs for m in hubs if k != m]

# Number of hubs to be used
p = 3

# Decision Variables
model.x = pyo.Var(pairs, hub_pairs, within=pyo.Binary)
model.y = pyo.Var(hubs, within=pyo.Binary)

# Objective function: Minimize total cost
def objective_rule(model):
    return sum(cost[(i, k, m, j)] * model.x[(i, j), (k, m)]
               for (i, j) in pairs for (k, m) in hub_pairs)

model.obj = pyo.Objective(rule=objective_rule, sense=pyo.minimize)

# Constraints
# Total hubs constraint
def total_hubs_constraint(model):
    return sum(model.y[k] for k in hubs) == p

model.total_hubs_constraint = pyo.Constraint(rule=total_hubs_constraint)

# Allocation constraint
def allocation_constraint(model, i, j):
    return sum(model.x[(i, j), (k, m)] for (k, m) in hub_pairs) == 1

model.allocation_constraint = pyo.Constraint(pairs, rule=allocation_constraint)

# # Flow constraint
# def flow_constraint(model, i, j, k):
#     return sum(model.x[(i, j), (k, m)] + model.x[(i, j), (m, k)] for m in hubs if k != m) <= model.y[k]

# model.flow_constraint = pyo.Constraint(pairs, hubs, rule=flow_constraint)

# First flow constraint
def flow_constraint_a(model, i, j, k):
    return sum(model.x[(i, j), (k, m)] for m in hubs if k != m) <= model.y[k]

model.flow_constraint_a = pyo.Constraint(pairs, hubs, rule=flow_constraint_a)

# Second flow constraint 
def flow_constraint_b(model, i, j, m):
    return sum(model.x[(i, j), (k, m)] for k in hubs if m != k) <= model.y[m]

model.flow_constraint_b = pyo.Constraint(pairs, hubs, rule=flow_constraint_b)

# Non-negativity and binary constraints are implicit in the variable definitions

# Solve the model
opt = pyo.SolverFactory('cbc', executable='bin\\cbc.exe')
results = opt.solve(model)
# model.pprint()

# Extract the objective function value
objective_value = pyo.value(model.obj)
print("\nObjective Function Value:", objective_value)

# Extract results
allocation_plan = pd.DataFrame(
    [(i, j, k, m, pyo.value(model.x[(i, j), (k, m)])) for (i, j) in pairs for (k, m) in hub_pairs if pyo.value(model.x[(i, j), (k, m)]) > 0],
    columns=['Origin', 'Destination', 'First Hub', 'Second Hub', 'Allocation']
)

print("\nAllocation Plan Table")
print(allocation_plan)
# Out:
# Objective Function Value: 1500.0
#
# Allocation Plan Table
#    Origin Destination First Hub Second Hub  Allocation
# 0       A           B      Hub4       Hub5         1.0
# 1       A           C      Hub4       Hub5         1.0
# 2       A           D      Hub1       Hub4         1.0
# 3       A           E      Hub4       Hub1         1.0
# 4       A           F      Hub4       Hub1         1.0
# 5       A           G      Hub4       Hub5         1.0
# 6       A           H      Hub4       Hub5         1.0
# 7       B           A      Hub5       Hub4         1.0
# 8       B           C      Hub4       Hub5         1.0
# 9       B           D      Hub5       Hub4         1.0
# 10      B           E      Hub4       Hub1         1.0
# 11      B           F      Hub4       Hub1         1.0
# 12      B           G      Hub4       Hub5         1.0
# 13      B           H      Hub5       Hub4         1.0
# 14      C           A      Hub5       Hub4         1.0
# 15      C           B      Hub5       Hub4         1.0
# 16      C           D      Hub5       Hub4         1.0
# 17      C           E      Hub5       Hub1         1.0
# 18      C           F      Hub5       Hub1         1.0
# 19      C           G      Hub5       Hub1         1.0
# 20      C           H      Hub5       Hub4         1.0
# 21      D           A      Hub4       Hub1         1.0
# 22      D           B      Hub4       Hub5         1.0
# 23      D           C      Hub4       Hub5         1.0
# 24      D           E      Hub4       Hub1         1.0
# 25      D           F      Hub4       Hub1         1.0
# 26      D           G      Hub4       Hub5         1.0
# 27      D           H      Hub4       Hub5         1.0
# 28      E           A      Hub1       Hub4         1.0
# 29      E           B      Hub1       Hub4         1.0
# 30      E           C      Hub1       Hub5         1.0
# 31      E           D      Hub1       Hub4         1.0
# 32      E           F      Hub4       Hub1         1.0
# 33      E           G      Hub1       Hub5         1.0
# 34      E           H      Hub1       Hub4         1.0
# 35      F           A      Hub1       Hub4         1.0
# 36      F           B      Hub1       Hub4         1.0
# 37      F           C      Hub1       Hub5         1.0
# 38      F           D      Hub1       Hub4         1.0
# 39      F           E      Hub1       Hub4         1.0
# 40      F           G      Hub1       Hub5         1.0
# 41      F           H      Hub1       Hub4         1.0
# 42      G           A      Hub5       Hub4         1.0
# 43      G           B      Hub5       Hub4         1.0
# 44      G           C      Hub1       Hub5         1.0
# 45      G           D      Hub5       Hub4         1.0
# 46      G           E      Hub5       Hub1         1.0
# 47      G           F      Hub5       Hub1         1.0
# 48      G           H      Hub5       Hub4         1.0
# 49      H           A      Hub5       Hub4         1.0
# 50      H           B      Hub4       Hub5         1.0
# 51      H           C      Hub4       Hub5         1.0
# 52      H           D      Hub5       Hub4         1.0
# 53      H           E      Hub4       Hub1         1.0
# 54      H           F      Hub4       Hub1         1.0
# 55      H           G      Hub4       Hub5         1.0

# %%
# create allocation_plan['Hubs'] column by concatenating 'First Hub' and 'Second Hub' columns in a list value
allocation_plan['Hubs'] = allocation_plan[['First Hub', 'Second Hub']].apply(list, axis=1)
allocation_plan = allocation_plan.drop(['First Hub', 'Second Hub', 'Allocation'], axis=1)

# %%
# create a origin - destination matrix containing Hubs column as the value of allocation_plan. so origin will be rows and destinations will be columns
allocation_plan = allocation_plan.pivot_table(index='Origin', columns='Destination', values='Hubs', aggfunc='sum')
allocation_plan
# Out:
# Destination             A             B             C             D  \
# Origin
# A                     NaN  [Hub4, Hub5]  [Hub4, Hub5]  [Hub1, Hub4]
# B            [Hub5, Hub4]           NaN  [Hub4, Hub5]  [Hub5, Hub4]
# C            [Hub5, Hub4]  [Hub5, Hub4]           NaN  [Hub5, Hub4]
# D            [Hub4, Hub1]  [Hub4, Hub5]  [Hub4, Hub5]           NaN
# E            [Hub1, Hub4]  [Hub1, Hub4]  [Hub1, Hub5]  [Hub1, Hub4]
# F            [Hub1, Hub4]  [Hub1, Hub5]  [Hub1, Hub5]  [Hub1, Hub4]
# G            [Hub5, Hub4]  [Hub5, Hub4]  [Hub1, Hub5]  [Hub5, Hub4]
# H            [Hub5, Hub4]  [Hub4, Hub5]  [Hub4, Hub5]  [Hub5, Hub4]
#
# Destination             E             F             G             H
# Origin
# A            [Hub4, Hub1]  [Hub4, Hub1]  [Hub4, Hub5]  [Hub4, Hub5]
# B            [Hub4, Hub1]  [Hub5, Hub1]  [Hub4, Hub5]  [Hub5, Hub4]
# C            [Hub5, Hub1]  [Hub5, Hub1]  [Hub5, Hub1]  [Hub5, Hub4]
# D            [Hub4, Hub1]  [Hub4, Hub1]  [Hub4, Hub5]  [Hub4, Hub5]
# E                     NaN  [Hub4, Hub1]  [Hub1, Hub5]  [Hub1, Hub4]
# F            [Hub1, Hub4]           NaN  [Hub1, Hub5]  [Hub1, Hub4]
# G            [Hub5, Hub1]  [Hub5, Hub1]           NaN  [Hub5, Hub4]
# H            [Hub4, Hub1]  [Hub4, Hub1]  [Hub4, Hub5]           NaN
